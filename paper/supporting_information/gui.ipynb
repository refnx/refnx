# %%
# use matplotlib for plotting
# %matplotlib notebook
import os.path

import refnx, scipy
from refnx.reflect import Motofit
from refnx.dataset import ReflectDataset

# %%
# version numbers used in this analysis
refnx.version.version, scipy.version.version
# Out:
# ('0.1.0', '1.1.0')

# %%
pth = os.path.join(os.path.dirname(refnx.__file__), 'analysis', 'test')
data_d2o = ReflectDataset(os.path.join(pth, 'c_PLP0011859_q.txt'))

# %%
app = Motofit()

# %%
app(data_d2o)
# Out:
# <img src="data:image/png;base64,..." width="900">
# VBox(children=(HBox(children=(Text(value='c_PLP0011859_q', description='dataset:', disabled=True), FloatText(v…
